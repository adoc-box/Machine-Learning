# %% [markdown]
# ### Created by: Anthony D. Cho
# ### Last update: 19.05.2021
#
# **Subject**: Keras (Multi-Layer Perceptron MLP) - Applied to Combined Cycle Power Plant data in regression problem

# %% [markdown]
# ## Libraries dependencies

# %%
from time import time
from pandas import read_csv
import matplotlib.pyplot as plt
from numpy import where, append
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

## tensorflow-Keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import metrics

# %% [markdown]
# ## Customized functions

# %%
def plot_history(history, width=12, height=6):
  """
  DESCRIPTION:
    Historical performance of the keras model
  
  INPUT:
    @param history: history of performance of fitted model
    @type history: tensorflow.python.keras.callbacks.History

    @param width: width of the graphic display
    @type width: int

    @param height: height of the graphic display
    @type height: int

  OUTPUT:
    A graphic
  """

  ## Metrics keys stored in tensorflow object
  keys = list(history.history.keys())

  ## Number of epoch used for fit the model
  epoch = range(1, len(history.epoch) +1)

  ## Check if validation set was used.
  withValidation = False
  for key in keys:
    if 'val' in key:
      withValidation = True

  ## Number of metrics 
  nMetrics = len(keys)
  if withValidation:
    nMetrics = nMetrics//2

  ## Plot-space instance
  plt.figure(figsize=(width, height))

  for i in range(nMetrics):
    plt.subplot(nMetrics, 1, i+1)

    ## Plot (train) metric value
    labelMetric = keys[i]
    metric = history.history[keys[i]]
    plt.plot(epoch, metric, 'o-', label=labelMetric)

    if withValidation:
      ## Plot (validation) metric value
      labelMetricVal = keys[i+nMetrics]
      metricVal = history.history[keys[i+nMetrics]]
      plt.plot(epoch, metricVal, 'o-', label=labelMetricVal)

    plt.xlim(epoch[0], epoch[-1])
    plt.legend()
    plt.grid()

  plt.xlabel('Epoch')
  plt.show()

# %% [markdown]
# # Problem (Regression): Combined Cycle Power Plant Data Set
#
# **Target**:  Predict the net hourly electrical energy output (PE) of the plant (Last column of dataset).

# %% [markdown]
# ## Data loading and preprocessing
#
# Source: [Combined Cycle Power Plant Data Set](https://archive.ics.uci.edu/ml/datasets/Combined+Cycle+Power+Plant) (UCI Repository)

# %%
start = time()
print('Loading data ...')

## Load data
data = read_csv('https://github.com/adoc-box/Datasets/blob/main/CCPP.csv?raw=true')

## Display Raw data
print('\n', data.head(), '\n')

## Data partition (hold-out validation)
print('Creating partition...')
trainValidationSet, testSet = train_test_split(data, train_size=0.85, random_state=0)
trainSet, validationSet = train_test_split(trainValidationSet, train_size=0.85, random_state=0)

## Data standardization (it return a numpy.ndarray)
print('Data standardizing...')
scaler = StandardScaler().fit(trainSet)
trainSet_scaled = scaler.transform(trainSet)
validationSet_scaled = scaler.transform(validationSet)
testSet_scaled = scaler.transform(testSet)

## Predictor (X) and target (y) assignment 
print('Predictor (X) and target (y) assignment... \n')
X_train, y_train = trainSet_scaled[:, :-1], trainSet_scaled[:, -1]
X_validation, y_validation = validationSet_scaled[:, :-1], validationSet_scaled[:, -1]
X_test, y_test = testSet_scaled[:, :-1], testSet_scaled[:, -1]

print('(train shape) X: {}, y: {}'.format(X_train.shape, y_train.shape))
print('(Validation shape) X: {}, y: {}'.format(X_validation.shape, y_validation.shape))
print('(test shape) X: {}, y: {}'.format(X_test.shape, y_test.shape), end='\n'*2)

print('Time spent[s]: ', time()-start)
# Out:
# Loading data ...
#
#        AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90
#
# Creating partition...
# Data standardizing...
# Predictor (X) and target (y) assignment...
#
# (train shape) X: (6912, 4), y: (6912,)
# (Validation shape) X: (1220, 4), y: (1220,)
# (test shape) X: (1436, 4), y: (1436,)
#
# Time spent[s]:  1.1488325595855713

# %% [markdown]
# ## Build model

# %%
## Model instance
model = Sequential(name='Regression')
model.add(layers.Dense(units=10, 
                       activation='relu', 
                       input_shape=(X_train.shape[1],), 
                       name='Hidden_01'))
model.add(layers.Dense(units=13, 
                       activation='relu', 
                       name='Hidden_02'))
model.add(layers.Dense(units=1,
                       activation='linear', 
                       name='Output'))

## Compiler setting
model.compile(optimizer='adam', 
              loss='mae', 
              metrics=[metrics.MeanSquaredError(), metrics.MeanAbsolutePercentageError()])

## Display model
model.summary()
# Out:
# Model: "Regression"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Hidden_01 (Dense)            (None, 10)                50
# _________________________________________________________________
# Hidden_02 (Dense)            (None, 13)                143
# _________________________________________________________________
# Output (Dense)               (None, 1)                 14
# =================================================================
# Total params: 207
# Trainable params: 207
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Fit model
start = time()
history = model.fit(x=X_train, y=y_train, validation_data=(X_validation, y_validation),
                    epochs=50, 
                    batch_size=32)
print('Time spent[s]: ', time()-start)
# Out:
# Epoch 1/50
# 216/216 [==============================] - 1s 4ms/step - loss: 0.5343 - mean_squared_error: 0.4497 - mean_absolute_percentage_error: 132.3997 - val_loss: 0.2277 - val_mean_squared_error: 0.0912 - val_mean_absolute_percentage_error: 146.2327
# Epoch 2/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.2161 - mean_squared_error: 0.0792 - mean_absolute_percentage_error: 327.9073 - val_loss: 0.2086 - val_mean_squared_error: 0.0769 - val_mean_absolute_percentage_error: 136.6908
# Epoch 3/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1987 - mean_squared_error: 0.0676 - mean_absolute_percentage_error: 240.3522 - val_loss: 0.2057 - val_mean_squared_error: 0.0749 - val_mean_absolute_percentage_error: 135.5227
# Epoch 4/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1945 - mean_squared_error: 0.0635 - mean_absolute_percentage_error: 159.2400 - val_loss: 0.2011 - val_mean_squared_error: 0.0714 - val_mean_absolute_percentage_error: 131.3315
# Epoch 5/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1958 - mean_squared_error: 0.0658 - mean_absolute_percentage_error: 184.7240 - val_loss: 0.2006 - val_mean_squared_error: 0.0718 - val_mean_absolute_percentage_error: 131.2798
# Epoch 6/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1940 - mean_squared_error: 0.0637 - mean_absolute_percentage_error: 192.6108 - val_loss: 0.1980 - val_mean_squared_error: 0.0698 - val_mean_absolute_percentage_error: 128.5870
# Epoch 7/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1920 - mean_squared_error: 0.0630 - mean_absolute_percentage_error: 118.0744 - val_loss: 0.2006 - val_mean_squared_error: 0.0725 - val_mean_absolute_percentage_error: 131.7046
# Epoch 8/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1878 - mean_squared_error: 0.0611 - mean_absolute_percentage_error: 214.6368 - val_loss: 0.1991 - val_mean_squared_error: 0.0706 - val_mean_absolute_percentage_error: 128.5542
# Epoch 9/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1924 - mean_squared_error: 0.0628 - mean_absolute_percentage_error: 490.5939 - val_loss: 0.1971 - val_mean_squared_error: 0.0690 - val_mean_absolute_percentage_error: 128.2857
# Epoch 10/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1879 - mean_squared_error: 0.0591 - mean_absolute_percentage_error: 123.7670 - val_loss: 0.1997 - val_mean_squared_error: 0.0716 - val_mean_absolute_percentage_error: 130.0651
# Epoch 11/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1907 - mean_squared_error: 0.0613 - mean_absolute_percentage_error: 135.0867 - val_loss: 0.1966 - val_mean_squared_error: 0.0687 - val_mean_absolute_percentage_error: 125.7055
# Epoch 12/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1881 - mean_squared_error: 0.0610 - mean_absolute_percentage_error: 128.6828 - val_loss: 0.1978 - val_mean_squared_error: 0.0702 - val_mean_absolute_percentage_error: 129.1448
# Epoch 13/50
# 216/216 [==============================] - 0s 1ms/step - loss: 0.1860 - mean_squared_error: 0.0616 - mean_absolute_percentage_error: 124.6378 - val_loss: 0.1987 - val_mean_squared_error: 0.0704 - val_mean_absolute_percentage_error: 129.9057
# Epoch 14/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1910 - mean_squared_error: 0.0638 - mean_absolute_percentage_error: 191.5448 - val_loss: 0.1974 - val_mean_squared_error: 0.0700 - val_mean_absolute_percentage_error: 127.8031
# Epoch 15/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1884 - mean_squared_error: 0.0598 - mean_absolute_percentage_error: 260.2715 - val_loss: 0.1965 - val_mean_squared_error: 0.0690 - val_mean_absolute_percentage_error: 124.5986
# Epoch 16/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1863 - mean_squared_error: 0.0582 - mean_absolute_percentage_error: 223.5044 - val_loss: 0.1985 - val_mean_squared_error: 0.0703 - val_mean_absolute_percentage_error: 127.5650
# Epoch 17/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1894 - mean_squared_error: 0.0612 - mean_absolute_percentage_error: 166.4212 - val_loss: 0.1960 - val_mean_squared_error: 0.0686 - val_mean_absolute_percentage_error: 123.9022
# Epoch 18/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1843 - mean_squared_error: 0.0568 - mean_absolute_percentage_error: 186.3120 - val_loss: 0.1951 - val_mean_squared_error: 0.0680 - val_mean_absolute_percentage_error: 122.9125
# Epoch 19/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1878 - mean_squared_error: 0.0614 - mean_absolute_percentage_error: 154.4050 - val_loss: 0.1964 - val_mean_squared_error: 0.0693 - val_mean_absolute_percentage_error: 125.3832
# Epoch 20/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1830 - mean_squared_error: 0.0598 - mean_absolute_percentage_error: 184.0661 - val_loss: 0.1990 - val_mean_squared_error: 0.0713 - val_mean_absolute_percentage_error: 126.2797
# Epoch 21/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1844 - mean_squared_error: 0.0575 - mean_absolute_percentage_error: 293.4543 - val_loss: 0.1945 - val_mean_squared_error: 0.0673 - val_mean_absolute_percentage_error: 120.7936
# Epoch 22/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1872 - mean_squared_error: 0.0601 - mean_absolute_percentage_error: 163.1151 - val_loss: 0.1983 - val_mean_squared_error: 0.0712 - val_mean_absolute_percentage_error: 124.7294
# Epoch 23/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1823 - mean_squared_error: 0.0562 - mean_absolute_percentage_error: 177.7260 - val_loss: 0.1948 - val_mean_squared_error: 0.0685 - val_mean_absolute_percentage_error: 124.7350
# Epoch 24/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1837 - mean_squared_error: 0.0642 - mean_absolute_percentage_error: 100.6302 - val_loss: 0.1939 - val_mean_squared_error: 0.0674 - val_mean_absolute_percentage_error: 119.5359
# Epoch 25/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1806 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 128.1323 - val_loss: 0.1944 - val_mean_squared_error: 0.0684 - val_mean_absolute_percentage_error: 122.8233
# Epoch 26/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1838 - mean_squared_error: 0.0598 - mean_absolute_percentage_error: 145.8361 - val_loss: 0.1946 - val_mean_squared_error: 0.0690 - val_mean_absolute_percentage_error: 123.3490
# Epoch 27/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1806 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 144.3080 - val_loss: 0.1947 - val_mean_squared_error: 0.0686 - val_mean_absolute_percentage_error: 124.0267
# Epoch 28/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1809 - mean_squared_error: 0.0557 - mean_absolute_percentage_error: 211.1904 - val_loss: 0.1942 - val_mean_squared_error: 0.0683 - val_mean_absolute_percentage_error: 121.9678
# Epoch 29/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1826 - mean_squared_error: 0.0566 - mean_absolute_percentage_error: 180.0023 - val_loss: 0.1958 - val_mean_squared_error: 0.0688 - val_mean_absolute_percentage_error: 121.3060
# Epoch 30/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1806 - mean_squared_error: 0.0577 - mean_absolute_percentage_error: 115.9655 - val_loss: 0.1944 - val_mean_squared_error: 0.0684 - val_mean_absolute_percentage_error: 124.3572
# Epoch 31/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1820 - mean_squared_error: 0.0572 - mean_absolute_percentage_error: 200.8203 - val_loss: 0.1943 - val_mean_squared_error: 0.0689 - val_mean_absolute_percentage_error: 128.0448
# Epoch 32/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1813 - mean_squared_error: 0.0571 - mean_absolute_percentage_error: 173.7068 - val_loss: 0.1979 - val_mean_squared_error: 0.0718 - val_mean_absolute_percentage_error: 129.3082
# Epoch 33/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1828 - mean_squared_error: 0.0570 - mean_absolute_percentage_error: 226.1718 - val_loss: 0.1938 - val_mean_squared_error: 0.0678 - val_mean_absolute_percentage_error: 121.5080
# Epoch 34/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1825 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 108.2943 - val_loss: 0.1926 - val_mean_squared_error: 0.0676 - val_mean_absolute_percentage_error: 123.1038
# Epoch 35/50
# 216/216 [==============================] - 0s 1ms/step - loss: 0.1843 - mean_squared_error: 0.0590 - mean_absolute_percentage_error: 147.8024 - val_loss: 0.1959 - val_mean_squared_error: 0.0700 - val_mean_absolute_percentage_error: 128.1362
# Epoch 36/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1868 - mean_squared_error: 0.0627 - mean_absolute_percentage_error: 124.1249 - val_loss: 0.1927 - val_mean_squared_error: 0.0679 - val_mean_absolute_percentage_error: 122.9711
# Epoch 37/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1857 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 162.5916 - val_loss: 0.1947 - val_mean_squared_error: 0.0694 - val_mean_absolute_percentage_error: 126.5787
# Epoch 38/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1784 - mean_squared_error: 0.0541 - mean_absolute_percentage_error: 88.2751 - val_loss: 0.1936 - val_mean_squared_error: 0.0685 - val_mean_absolute_percentage_error: 124.3096
# Epoch 39/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1785 - mean_squared_error: 0.0552 - mean_absolute_percentage_error: 90.1507 - val_loss: 0.1949 - val_mean_squared_error: 0.0697 - val_mean_absolute_percentage_error: 127.0972
# Epoch 40/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1799 - mean_squared_error: 0.0565 - mean_absolute_percentage_error: 145.1883 - val_loss: 0.1953 - val_mean_squared_error: 0.0694 - val_mean_absolute_percentage_error: 126.1258
# Epoch 41/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1824 - mean_squared_error: 0.0591 - mean_absolute_percentage_error: 122.6474 - val_loss: 0.1933 - val_mean_squared_error: 0.0679 - val_mean_absolute_percentage_error: 122.5658
# Epoch 42/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1810 - mean_squared_error: 0.0584 - mean_absolute_percentage_error: 123.0173 - val_loss: 0.1921 - val_mean_squared_error: 0.0674 - val_mean_absolute_percentage_error: 124.0568
# Epoch 43/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1783 - mean_squared_error: 0.0549 - mean_absolute_percentage_error: 121.0750 - val_loss: 0.1933 - val_mean_squared_error: 0.0683 - val_mean_absolute_percentage_error: 125.9676
# Epoch 44/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1797 - mean_squared_error: 0.0589 - mean_absolute_percentage_error: 154.7824 - val_loss: 0.1922 - val_mean_squared_error: 0.0675 - val_mean_absolute_percentage_error: 124.3648
# Epoch 45/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1795 - mean_squared_error: 0.0564 - mean_absolute_percentage_error: 299.2149 - val_loss: 0.1929 - val_mean_squared_error: 0.0685 - val_mean_absolute_percentage_error: 125.2830
# Epoch 46/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1798 - mean_squared_error: 0.0583 - mean_absolute_percentage_error: 157.7425 - val_loss: 0.1933 - val_mean_squared_error: 0.0680 - val_mean_absolute_percentage_error: 120.9546
# Epoch 47/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1813 - mean_squared_error: 0.0595 - mean_absolute_percentage_error: 203.2940 - val_loss: 0.1914 - val_mean_squared_error: 0.0668 - val_mean_absolute_percentage_error: 121.5420
# Epoch 48/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1792 - mean_squared_error: 0.0552 - mean_absolute_percentage_error: 259.0344 - val_loss: 0.1924 - val_mean_squared_error: 0.0680 - val_mean_absolute_percentage_error: 123.0732
# Epoch 49/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1803 - mean_squared_error: 0.0574 - mean_absolute_percentage_error: 146.8103 - val_loss: 0.1914 - val_mean_squared_error: 0.0672 - val_mean_absolute_percentage_error: 122.6105
# Epoch 50/50
# 216/216 [==============================] - 0s 2ms/step - loss: 0.1797 - mean_squared_error: 0.0602 - mean_absolute_percentage_error: 105.4214 - val_loss: 0.1942 - val_mean_squared_error: 0.0691 - val_mean_absolute_percentage_error: 123.7040
# Time spent[s]:  18.219892263412476

# %% [markdown]
# ## Model performances display

# %%
## Display performances
plot_history(history, width=14, height=8)

## Compute metrics using test set in the model
model.evaluate(X_test, y_test)
# Out:
# 45/45 [==============================] - 0s 1ms/step - loss: 0.1807 - mean_squared_error: 0.0548 - mean_absolute_percentage_error: 59.9221
# [0.18074728548526764, 0.05482667312026024, 59.92213439941406]

# %% [markdown]
# ## Predictions

# %%
## Compute prediction using test set
prediction = model.predict(X_test)

# %%
## Un-scale target and output
y_test_unscaled = y_test*scaler.scale_[-1] + scaler.mean_[-1]
prediction_unscaled = prediction*scaler.scale_[-1] + scaler.mean_[-1]

# %%
## Plot partially raw data and predictions

s, t = 0, 300
plt.figure(figsize=(17, 4))
plt.plot(y_test_unscaled[s:t], alpha=0.7, label='Ground truth')
plt.plot(prediction_unscaled[s:t], alpha=0.7, label='Prediction')
plt.legend(loc=[0.792, 1.01], ncol=2)
plt.title('Electrical energy'); plt.ylabel('W')
plt.xlim([s,t]); plt.show()

# %% [markdown]
# ## Best model
#
# Looking into the performance charts, it seems to stabilize (or kind of overfitting) starting at epoch 24 in the mean absolute percentage error (MAPE) metric.

# %%
## Join Tran and validate set 
X = append(X_train, X_validation, axis=0)
y = append(y_train, y_validation, axis=0)

print('(train shape) X: {}, y: {}'.format(X.shape, y.shape))
# Out:
# (train shape) X: (8132, 4), y: (8132,)

# %%
## Model instance
model = Sequential(name='Regression')
model.add(layers.Dense(units=10, 
                       activation='relu', 
                       input_shape=(X.shape[1],), 
                       name='Hidden_01'))
model.add(layers.Dense(units=13, 
                       activation='relu', 
                       name='Hidden_02'))
model.add(layers.Dense(units=1,
                       activation='linear', 
                       name='Output'))

## Compiler setting
model.compile(optimizer='adam', 
              loss='mae', 
              metrics=[metrics.MeanSquaredError(), metrics.MeanAbsolutePercentageError()])

# %%
## Fit model
start = time()
history = model.fit(x=X, y=y,
                    epochs=24, 
                    batch_size=32)
print('Time spent[s]: ', time()-start)
# Out:
# Epoch 1/24
# 255/255 [==============================] - 1s 1ms/step - loss: 0.4322 - mean_squared_error: 0.3439 - mean_absolute_percentage_error: 151.7463
# Epoch 2/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.2014 - mean_squared_error: 0.0680 - mean_absolute_percentage_error: 233.8198
# Epoch 3/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.2009 - mean_squared_error: 0.0706 - mean_absolute_percentage_error: 360.9602
# Epoch 4/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1944 - mean_squared_error: 0.0647 - mean_absolute_percentage_error: 217.4952
# Epoch 5/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1933 - mean_squared_error: 0.0643 - mean_absolute_percentage_error: 154.4624
# Epoch 6/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1933 - mean_squared_error: 0.0642 - mean_absolute_percentage_error: 212.7960
# Epoch 7/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1926 - mean_squared_error: 0.0681 - mean_absolute_percentage_error: 162.5981
# Epoch 8/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1890 - mean_squared_error: 0.0601 - mean_absolute_percentage_error: 168.3735
# Epoch 9/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1888 - mean_squared_error: 0.0609 - mean_absolute_percentage_error: 176.3106
# Epoch 10/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1887 - mean_squared_error: 0.0614 - mean_absolute_percentage_error: 124.6009
# Epoch 11/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1879 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 117.4867
# Epoch 12/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1866 - mean_squared_error: 0.0613 - mean_absolute_percentage_error: 141.5867
# Epoch 13/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1888 - mean_squared_error: 0.0623 - mean_absolute_percentage_error: 209.6644
# Epoch 14/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1888 - mean_squared_error: 0.0645 - mean_absolute_percentage_error: 306.7558
# Epoch 15/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1916 - mean_squared_error: 0.0659 - mean_absolute_percentage_error: 357.4320
# Epoch 16/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1859 - mean_squared_error: 0.0594 - mean_absolute_percentage_error: 121.0132
# Epoch 17/24
# 255/255 [==============================] - 0s 2ms/step - loss: 0.1862 - mean_squared_error: 0.0597 - mean_absolute_percentage_error: 237.5781
# Epoch 18/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1874 - mean_squared_error: 0.0602 - mean_absolute_percentage_error: 367.9670
# Epoch 19/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1882 - mean_squared_error: 0.0608 - mean_absolute_percentage_error: 347.9006
# Epoch 20/24
# 255/255 [==============================] - 0s 2ms/step - loss: 0.1884 - mean_squared_error: 0.0619 - mean_absolute_percentage_error: 144.6581
# Epoch 21/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1879 - mean_squared_error: 0.0632 - mean_absolute_percentage_error: 183.4971
# Epoch 22/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1832 - mean_squared_error: 0.0580 - mean_absolute_percentage_error: 170.3595
# Epoch 23/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1828 - mean_squared_error: 0.0591 - mean_absolute_percentage_error: 187.2591
# Epoch 24/24
# 255/255 [==============================] - 0s 1ms/step - loss: 0.1880 - mean_squared_error: 0.0632 - mean_absolute_percentage_error: 216.1150
# Time spent[s]:  8.896004676818848

# %%
## Compute prediction using test set
prediction = model.predict(X_test)

## Un-scale target and output
y_test_unscaled = y_test*scaler.scale_[-1] + scaler.mean_[-1]
prediction_unscaled = prediction*scaler.scale_[-1] + scaler.mean_[-1]

# %%
## Plot partially raw data and predictions

s, t = 0, 300
plt.figure(figsize=(17, 4))
plt.plot(y_test_unscaled[s:t], alpha=0.7, label='Ground truth')
plt.plot(prediction_unscaled[s:t], alpha=0.7, label='Prediction')
plt.legend(loc=[0.792, 1.01], ncol=2)
plt.title('Electrical energy'); plt.ylabel('W')
plt.xlim([s,t]); plt.show()
